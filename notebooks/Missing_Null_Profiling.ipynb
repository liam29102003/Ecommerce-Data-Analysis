# %%
# %sql
-- Null counts per column in customers
SELECT
  COUNT(*) AS total_rows,
  COUNT(*) - COUNT(city) AS null_city,
  COUNT(*) - COUNT(region_id) AS null_region,
  COUNT(*) - COUNT(birth_date) AS null_birth_date,
  COUNT(*) - COUNT(customer_segment) AS null_segment,
  COUNT(*) - COUNT(acquisition_channel) AS null_channel
FROM ecommerce.base.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th><th>null_city</th><th>null_region</th><th>null_birth_date</th><th>null_segment</th><th>null_channel</th></tr></thead><tbody><tr><td>15045</td><td>45</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
-- Null counts in products (brand is documented as partially null)
SELECT
  COUNT(*) AS total_rows,
  COUNT(*) - COUNT(brand) AS null_brand,
  COUNT(*) - COUNT(unit_cost) AS null_cost,
  COUNT(*) - COUNT(list_price) AS null_price
FROM ecommerce.base.products;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th><th>null_brand</th><th>null_cost</th><th>null_price</th></tr></thead><tbody><tr><td>500</td><td>2</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
-- Null counts in orders (shipping_method documented as sometimes null)
SELECT
  COUNT(*) AS total_rows,
  COUNT(*) - COUNT(shipping_method) AS null_shipping_method,
  COUNT(*) - COUNT(store_id) AS null_store,
  COUNT(*) - COUNT(discount_amount) AS null_discount
FROM ecommerce.base.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th><th>null_shipping_method</th><th>null_store</th><th>null_discount</th></tr></thead><tbody><tr><td>120000</td><td>240</td><td>0</td><td>0</td></tr></tbody></table></div>
